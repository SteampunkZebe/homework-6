# %% [raw]
# binary
# 1 Look at the big picture.
# 2 Get the data.
# 3 Discover and visualize the data to gain insights.
# 4 Prepare the data for Machine Learning algorithms.
# 5 Select a model and train it.
# 6 Fine-tune your model.
# 7 Present your solution.
# 8 Launch, monitor, and maintain your system.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
import pandas as pd
import os
from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import fetch_mldata
from sklearn import preprocessing
from sklearn.feature_selection import SelectPercentile
from sklearn.linear_model import LinearRegression
import math
#loading the data in
los=pd.read_csv(os.path.join("LasVegasTripAdvisorReviews-Dataset (1).csv"))
print(los)
# Out:
#     User country  Nr. reviews  Nr. hotel reviews  Helpful votes  Score  Pool  \
# 0            USA           11                  4             13      5     0
# 1            USA          119                 21             75      3     0
# 2            USA           36                  9             25      5     0
# 3             UK           14                  7             14      4     0
# 4         Canada            5                  5              2      4     0
# 5         Canada           31                  8             27      3     0
# 6             UK           45                 12             46      4     0
# 7            USA            2                  1              4      4     0
# 8          India           24                  3              8      4     0
# 9         Canada           12                  7             11      3     0
# 10           USA          102                 24             58      2     0
# ...

# %%
#visualising the data
y=los["Hotel stars"]
plt.plot(y)

# %%
#train test split picking the classifier and running it with adjusted hyperparameters
X_train,X_test,y_train,y_test=train_test_split(los.iloc[:,4:10], y, test_size=0.25, random_state=42)
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier(n_estimators=10,min_samples_leaf=10, random_state=42)
rfc.fit(X_train, y_train)

print(rfc.score(X_train,y_train))
print(rfc.score(X_test,y_test))
# Out:
# 0.679894179894
# 0.690476190476
